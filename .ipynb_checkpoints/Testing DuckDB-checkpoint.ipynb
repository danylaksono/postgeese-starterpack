# %% [markdown]
# # Basic DuckDB 🦆 for Spatial Analysis Setup
#
# ~ Dany Laksono

# %% [markdown]
# The following is a basic steps for setting up duckdb and it's spatial extension, [PostGEESE](https://duckdb.org/2023/04/28/spatial.html). This notebook can be used as a starting point for building poor man's data lake (or to be precise, data 'pond') for geospatial data science analytics using DuckDB's latest [Spatial Extension](https://github.com/duckdblabs/duckdb_spatial).
#
# Credit to:
# - [Mark Litwintschik](https://tech.marksblogg.com/duckdb-geospatial-gis.html), one of the very first articles discussing about the wonderful of DuckDB to the geospatial community
# - [Mark Forrest](https://www.youtube.com/watch?v=ljzpm3Mrw-I) for the inspiration.
# - [Wei-Meng Lee](https://towardsdatascience.com/running-sql-queries-in-jupyter-notebook-using-jupysql-duckdb-and-mysql-3c53fbe40f8d) for the examples on JupySQL

# %% [markdown]
# ## Preparation and Installation

# %%
# %%writefile requirements.txt
#
# duckdb
# jupysql
# duckdb-engine
# Out:
# Overwriting requirements.txt

# %%
# !pip install -r requirements.txt --quiet

# %%
import duckdb
import pandas as pd

# %% [markdown]
# Setting up the JupySQL extension

# %%
# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# Out:
# /home/danylaksono/miniconda3/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %% [markdown]
# The extension allows us to use `%sql` syntax in a jupyter lab cell for a single line SQL command, and `%%sql` syntax for multiline SQL command, as you'll see in the following cells

# %% [markdown]
# ## Setup DuckDB and Install Spatial Extension

# %% [markdown]
# Initialize a DuckDB database in-memory

# %%
# %sql duckdb:///:memory:

# %% [markdown]
# Install the [spatial extension](https://duckdb.org/docs/extensions/spatial).

# %%
# %%sql
# INSTALL spatial;
# LOAD spatial;
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# DuckDB's [HTTPFS Extension](https://duckdb.org/docs/extensions/httpfs.html) allows us to load data into DuckDB _remotely_. Imagine the performance gained by taking advantage of S3's partial load for parquet data, while at the same time loading the data and processing them in DuckDB.
#
# [This article](https://dagster.io/blog/duckdb-data-lake) by Dagster actually explores the possibility of building a working Data 'Pond' using DuckDB and S3 to store parquet files.

# %%
# %%sql
# INSTALL httpfs;
# LOAD httpfs;
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# -- run once
# INSTALL parquet;
# -- run before usage
# LOAD parquet;
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Test a simple spatial operation

# %%
# %%sql
# select st_point(0,0);
# Out:
#                                       st_point(0, 0)
# 0  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...

# %% [markdown]
# if there's nothing wrong then congrats, it works!

# %% [markdown]
# ## A Simple Use Case

# %% [markdown]
# In the following cells, we'll try and have some experiments on DuckDB. We'll read a GeoJSON data of London Trees (obtained from [here](https://data.london.gov.uk/dataset/local-authority-maintained-trees) and converted to GeoJSON for the demo). Just for the sake of simplicity, we'll try to calculate the distance between all trees in London and a point.

# %%
# %%sql
# create or replace table trees as
# select *, ST_GeomFromWKB(wkb_geometry) as geom
# from st_read('./london_trees.geojson')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='100%'), style=ProgressStyle(bar_color='black'))
#     Count
# 0  817150

# %% [markdown]
# Show the dataset. Pay attention that SQL queries in DuckDB can be [simplified](https://duckdb.org/2022/05/04/friendlier-sql.html), so in the example below, we're omitting the 'SELECT *' and just go with 'FROM ... LIMIT' and so forth.

# %%
# %%sql
# from trees limit 10;
# Out:
#    fid  objectid gla_tree_n tree_name     taxon_name common_nam   age  \
# 0    1         1      Other      None  Abies grandis  Grand fir  None
# 1    2         2      Other      None  Abies grandis  Grand fir  None
# 2    3         3      Other      None  Abies grandis  Grand fir  None
# 3    4         4      Other      None  Abies grandis  Grand fir  None
# 4    5         5      Other      None  Abies grandis  Grand fir  None
# 5    6         6      Other      None  Abies grandis  Grand fir  None
# 6    7         7      Other      None  Abies grandis  Grand fir  None
# 7    8         8      Other      None  Abies grandis  Grand fir  None
# 8    9         9      Other      None  Abies grandis  Grand fir  None
# 9   10        10      Other      None  Abies grandis  Grand fir  None
#
#               age_group   height_m spread_m  ... diameter_a   dbh_group  \
# 0  Early mature (16-30)  10 to 15m     None  ...       None  21 to 40cm
# 1  Early mature (16-30)  10 to 15m     None  ...       None  21 to 40cm
# 2  Early mature (16-30)  05 to 10m     None  ...       None  21 to 40cm
# 3        Mature (31-80)  10 to 15m     None  ...       None  41 to 70cm
# 4        Mature (31-80)  10 to 15m     None  ...       None  41 to 70cm
# 5        Mature (31-80)  10 to 15m     None  ...       None  41 to 70cm
# 6  Early mature (16-30)  15 to 20m     None  ...       None  21 to 40cm
# 7  Early mature (16-30)  10 to 15m     None  ...       None  21 to 40cm
# 8        Mature (31-80)  10 to 15m     None  ...       None  21 to 40cm
# 9        Mature (31-80)  10 to 15m     None  ...       None  41 to 70cm
#
#   longitude   latitude   condition load_date   updated  \
# 0 -0.291147  51.361893  Reasonable  20210318  20210715
# 1 -0.291122  51.361914  Reasonable  20210318  20210715
# 2 -0.290943  51.387016  Reasonable  20210318  20210715
# 3 -0.288572  51.387405  Reasonable  20210318  20210715
# 4 -0.285025  51.388872  Reasonable  20210318  20210715
# 5 -0.284745  51.389057  Reasonable  20210318  20210715
# 6 -0.287251  51.387745  Reasonable  20210318  20210715
# 7 -0.276019  51.419150  Reasonable  20210318  20210715
# 8 -0.275347  51.419819  Reasonable  20210318  20210715
# 9 -0.275379  51.419954  Reasonable  20210318  20210715
#
#                                         wkb_geometry  \
# 0  b"\x01\x01\x00\x00\x009\x95N\x1c'\xa2\xd2\xbf\...
# 1  b'\x01\x01\x00\x00\x00t\x12B\xee\xbf\xa1\xd2\x...
# 2  b'\x01\x01\x00\x00\x00\xe2\x9c\x85\xfb\xd0\x9e...
# 3  b'\x01\x01\x00\x00\x00\x1d\x84\x0c&\xf6w\xd2\x...
# 4  b'\x01\x01\x00\x00\x00>o\xf0\xa6\xd7=\xd2\xbf\...
# 5  b'\x01\x01\x00\x00\x00\xf0D\xf7IA9\xd2\xbfn\xa...
# 6  b'\x01\x01\x00\x00\x00\xf9)\x12<Sb\xd2\xbf\xa7...
# 7  b'\x01\x01\x00\x00\x00\x10\x11/6J\xaa\xd1\xbf\...
# 8  b'\x01\x01\x00\x00\x00A\xcfM8G\x9f\xd1\xbf\xa7...
# 9  b'\x01\x01\x00\x00\x00\x02L\xd7\x1b\xce\x9f\xd...
#
#                                                 geom  \
# 0  b"\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 1  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 2  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 3  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 4  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 5  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 6  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 7  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 8  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 9  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
#
#                                      pointidx
# 0        {'x': -0.29114702, 'y': 51.36189321}
# 1        {'x': -0.29112242, 'y': 51.36191363}
# 2        {'x': -0.29094338, 'y': 51.38701648}
# 3        {'x': -0.28857187, 'y': 51.38740453}
# 4        {'x': -0.28502456, 'y': 51.38887244}
# 5        {'x': -0.28474457, 'y': 51.38905719}
# 6        {'x': -0.28725129, 'y': 51.38774494}
# 7        {'x': -0.27601867, 'y': 51.41915025}
# 8  {'x': -0.27534657, 'y': 51.41981857000001}
# 9        {'x': -0.27537873, 'y': 51.41995366}
#
# [10 rows x 21 columns]

# %% [markdown]
# Notice the EXCLUDE? yeah that's DuckDB's [special SQL](https://duckdb.org/2022/05/04/friendlier-sql.html#select--exclude) syntax!

# %%
# %%sql
# select * exclude (objectid, gla_tree_n, tree_name, age, spread_m, wkb_geometry) from trees limit 10
# Out:
#    fid     taxon_name common_nam             age_group   height_m canopy_spr  \
# 0    1  Abies grandis  Grand fir  Early mature (16-30)  10 to 15m  00 to 05m
# 1    2  Abies grandis  Grand fir  Early mature (16-30)  10 to 15m  00 to 05m
# 2    3  Abies grandis  Grand fir  Early mature (16-30)  05 to 10m  05 to 10m
# 3    4  Abies grandis  Grand fir        Mature (31-80)  10 to 15m  05 to 10m
# 4    5  Abies grandis  Grand fir        Mature (31-80)  10 to 15m  05 to 10m
# 5    6  Abies grandis  Grand fir        Mature (31-80)  10 to 15m  05 to 10m
# 6    7  Abies grandis  Grand fir  Early mature (16-30)  15 to 20m  05 to 10m
# 7    8  Abies grandis  Grand fir  Early mature (16-30)  10 to 15m  00 to 05m
# 8    9  Abies grandis  Grand fir        Mature (31-80)  10 to 15m  05 to 10m
# 9   10  Abies grandis  Grand fir        Mature (31-80)  10 to 15m  05 to 10m
#
#   diameter_a   dbh_group  longitude   latitude   condition  load_date  \
# 0       None  21 to 40cm  -0.291147  51.361893  Reasonable   20210318
# 1       None  21 to 40cm  -0.291122  51.361914  Reasonable   20210318
# 2       None  21 to 40cm  -0.290943  51.387016  Reasonable   20210318
# 3       None  41 to 70cm  -0.288572  51.387405  Reasonable   20210318
# 4       None  41 to 70cm  -0.285025  51.388872  Reasonable   20210318
# 5       None  41 to 70cm  -0.284745  51.389057  Reasonable   20210318
# 6       None  21 to 40cm  -0.287251  51.387745  Reasonable   20210318
# 7       None  21 to 40cm  -0.276019  51.419150  Reasonable   20210318
# 8       None  21 to 40cm  -0.275347  51.419819  Reasonable   20210318
# 9       None  41 to 70cm  -0.275379  51.419954  Reasonable   20210318
#
#     updated                                               geom  \
# 0  20210715  b"\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 1  20210715  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 2  20210715  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 3  20210715  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 4  20210715  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 5  20210715  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 6  20210715  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 7  20210715  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 8  20210715  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
# 9  20210715  b'\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00...
#
#                                      pointidx
# 0        {'x': -0.29114702, 'y': 51.36189321}
# 1        {'x': -0.29112242, 'y': 51.36191363}
# 2        {'x': -0.29094338, 'y': 51.38701648}
# 3        {'x': -0.28857187, 'y': 51.38740453}
# 4        {'x': -0.28502456, 'y': 51.38887244}
# 5        {'x': -0.28474457, 'y': 51.38905719}
# 6        {'x': -0.28725129, 'y': 51.38774494}
# 7        {'x': -0.27601867, 'y': 51.41915025}
# 8  {'x': -0.27534657, 'y': 51.41981857000001}
# 9        {'x': -0.27537873, 'y': 51.41995366}

# %%
# %%sql
# select age_group, height_m, condition, count(*) as num_of_data
# from trees
# group by all;
# Out:
#                 age_group   height_m   condition  num_of_data
# 0    Early mature (16-30)  10 to 15m  Reasonable          700
# 1    Early mature (16-30)  05 to 10m  Reasonable         3450
# 2          Mature (31-80)  10 to 15m  Reasonable         1631
# 3    Early mature (16-30)  15 to 20m  Reasonable          115
# 4            Young (0-15)  00 to 05m  Reasonable         3450
# ..                    ...        ...         ...          ...
# 782    Veteran (over 150)       None        None          425
# 783    Veteran (over 150)         13        None           59
# 784    Veteran (over 150)         20        None            2
# 785    Veteran (over 150)         12        None          116
# 786                  None        6.8        None            1
#
# [787 rows x 4 columns]

# %% [markdown]
# Here we're stepping up the game a little bit further. We can use DuckDB's [Native Geometry System](https://github.com/duckdblabs/duckdb_spatial#multi-tiered-geometry-type-system), which provides another performance gain for geospatial analysis

# %%
# %%sql
# alter table trees add column pointidx point_2d;
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# update trees set pointidx = geom::point_2d;
# Out:
#     Count
# 0  817150

# %% [markdown]
# Now we calculate the distance. In this case, we'll use the GEOM column, which follows the Simple Features geometry model. This geom can be used for interoperability, since it will have the same structure with other standardised geometry (such as Geopandas or PostGIS).
#
# Notice that this operation is quite fast: after all, we're calculating ~800k distances!

# %%
# %%time
# %%sql
select common_nam, 
st_distance(geom, st_point(51.65345594544537, -0.19995380867530435)) as distance 
from trees
# Out:
# CPU times: user 1.28 s, sys: 377 ms, total: 1.66 s
# Wall time: 2.03 s
#           common_nam   distance
# 0          Grand fir  73.190613
# 1          Grand fir  73.190610
# 2          Grand fir  73.208170
# 3          Grand fir  73.206761
# 4          Grand fir  73.205278
# ...              ...        ...
# 817145        Cherry  73.082810
# 817146      Hornbeam  73.081050
# 817147      Sycamore  73.051724
# 817148  False acacia  73.051434
# 817149  False acacia  73.051429
#
# [817150 rows x 2 columns]

# %% [markdown]
# Now let's try to calculate them again, but this time we'll use DuckDB's Native Geometry, which we've built before.

# %%
# %%time
# %%sql
select common_nam, 
st_distance(pointidx, st_point(51.65345594544537, -0.19995380867530435)::point_2d) as distance from trees
# Out:
# CPU times: user 1.21 s, sys: 39.8 ms, total: 1.24 s
# Wall time: 1.61 s
#           common_nam   distance
# 0          Grand fir  73.190613
# 1          Grand fir  73.190610
# 2          Grand fir  73.208170
# 3          Grand fir  73.206761
# 4          Grand fir  73.205278
# ...              ...        ...
# 817145        Cherry  73.082810
# 817146      Hornbeam  73.081050
# 817147      Sycamore  73.051724
# 817148  False acacia  73.051434
# 817149  False acacia  73.051429
#
# [817150 rows x 2 columns]

# %% [markdown]
# And that's ever faster!
# See [here](https://colab.research.google.com/drive/1e1beWqYOcFidKl2IxHtxT5s9i_6KYuNY) for the comparison between Pandas and DuckDB
#
#
#
# So I rest my case: Q.E.D.

# %% [markdown]
# ## What's next?

# %% [markdown]
# At the moment, the spatial analysis functions in DuckDB is still in it's infancy, but we can expect them to grow overtime. Even now, we can explore some of the functionalities, such as reading data directly from [PostgreSQL](https://duckdb.org/docs/extensions/postgres_scanner). There are also some useful extensions, such as [Isaac Brodsky's H3](https://github.com/isaacbrodsky/h3-duckdb) which could really be a game changer for processing large geospatial datasets. Have fun!
